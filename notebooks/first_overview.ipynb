# %%
# %cd /home/thenodev/Projects/GutenbergOnomasticsExplorer
# Out:
# /home/thenodev/Projects/GutenbergOnomasticsExplorer

# %% [markdown]
# ## LangChain Gutenbergloader

# %%
import langchain

# %%
from langchain.document_loaders import GutenbergLoader

# %%
loader = GutenbergLoader("https://www.gutenberg.org/cache/epub/71057/pg71057.txt")

# %%
data = loader.load()

# %% [markdown]
# ## Prototype MetadataLibrary Construction

# %%
import tarfile
import os

def constructLibrary(libraryPath:str="./", rdf_path:str="./rdf-files.tar"):
    print(f"Constructing Library this may take some time")

    # Unzip Metadata Lake
    buildMetadata(rdf_path)


    print("Library Constructed Succesfully in {libraryPath}")
    return

def buildMetadata(rdf_path):
    print(f"Building metadata Lake using the following rdf-file: {rdf_path}")
    with tarfile.open(rdf_path, "r") as tar:
        tar.extractall()
    print("Metadata Lake build Sucesfully")
    return

# %%
import xml.etree.ElementTree as ET

def parseMetaData(directory='./notebooks/cache/epub/'):
    metadata = []

    for root, dirs, files in os.walk(directory):
        for filename in files:
            print(filename)
            if filename.endswith(".rdf"):  # Process only RDF files
                filepath = os.path.join(root, filename)
                # Recursively iterate through the directory and its subdirectories
                # Open and parse the RDF file
                tree = ET.parse(filepath)
                root = tree.getroot()
                
                # Extract the desired attributes from the RDF XML
                for element in root.findall(".//{http://www.gutenberg.org/2009/pgterms/}file"):
                    url = element.attrib['{http://www.w3.org/1999/02/22-rdf-syntax-ns#}about']
                    if url.endswith(".txt.utf-8"):  # Replace with the actual tag you want to extract
                        # Do something with the attribute value
                        break


                for element in root.find(".//{http://purl.org/dc/elements/1.1/}title"):
                    title = element.text
                        
                for element in root.find(".//{http://purl.org/dc/terms/}issued"):
                    issued = element.text
                        
                for element in root.find('.//{http://www.gutenberg.org/2009/pgterms/}name'):
                    # extract author name alias
                    author = element[0].text

                for element in root.find('.//{http://www.gutenberg.org/2009/pgterms/}birthdate'):
                    # extract author name alias
                    birthday = element[0].text

                for element in root.find('.//http://www.gutenberg.org/2009/pgterms/}deathdate'):
                    # extract author name alias
                    deathdate = element[0].text

                for element in root.find('.//{http://www.gutenberg.org/2009/pgterms/}alias'):
                    # extract author name alias
                    alias = element[0].text

                element = root.find('.//{http://purl.org/dc/terms/}language')
                element = element.find('.//{http://www.w3.org/1999/02/22-rdf-syntax-ns#}value')
                language = element.text

                metadata.append(
                    {
                        'title': title,
                        'issued': issued,
                        'author': author,
                        'birthday': birthday,
                        'deathdate': deathdate,
                        'alias':alias,
                        'url':url,
                        'language':language
                    }
                )            
    
    return metadata

# %% [markdown]
# ## Parsing RDF FIleusing rdflib

# %%
from rdflib import Graph, Namespace
import pandas as pd

def parsemetadataNEW(path):
    rdf = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
    dcterms = Namespace("http://purl.org/dc/terms/")
    pgterms = Namespace("http://www.gutenberg.org/2009/pgterms/")


    books_metadata = []

    for root, dirs, files in os.walk(path):
        for filename in files:
            if filename.endswith(".rdf"):  # Process only RDF files
                filepath = os.path.join(root, filename)
                # Recursively iterate through the directory and its subdirectories
                # Open and parse the RDF file
                # Define the namespaces used in the RDF document

                g = Graph()
                g.parse(filepath)

                # Retrieve the relevant information from the RDF document and add it to the dataframe
                for ebook in g.subjects(rdf.type, pgterms.ebook):
                    row = {}
                    row["publisher"] = g.value(ebook, dcterms.publisher)
                    row["license"] = g.value(ebook, dcterms.license)
                    row["issued"] = g.value(ebook, dcterms.issued)
                    row["rights"] = g.value(ebook, dcterms.rights)
                    row["downloads"] = g.value(ebook, pgterms.downloads)
                    
                    creator = g.value(ebook, dcterms.creator)
                    row["creator_name"] = g.value(creator, pgterms.name)
                    row["creator_birthdate"] = g.value(creator, pgterms.birthdate)
                    row["creator_deathdate"] = g.value(creator, pgterms.deathdate)
                    row["creator_alias"] = g.value(creator, pgterms.alias)
                    row["creator_webpage"] = g.value(creator, pgterms.webpage)
                    
                    row["title"] = g.value(ebook, dcterms.title)
                    row["description"] = g.value(ebook, dcterms.description)
                    
                    language = g.value(ebook, dcterms.language)
                    row["language"] = g.value(language, rdf.value)
                    
                    subjects = g.objects(ebook, dcterms.subject)
                    subjects = [g.value(s, rdf.value) for s in subjects]
                    row["subject1"] = subjects[0] if len(subjects) > 0 else None
                    row["subject2"] = subjects[1] if len(subjects) > 1 else None
                    row["subject3"] = subjects[2] if len(subjects) > 2 else None
                    row["subject4"] = subjects[3] if len(subjects) > 3 else None
                    
                    bookshelves = g.objects(ebook, pgterms.bookshelf)
                    bookshelves = [g.value(b, rdf.value) for b in bookshelves]
                    row["bookshelf1"] = bookshelves[0] if len(bookshelves) > 0 else None
                    row["bookshelf2"] = bookshelves[1] if len(bookshelves) > 1 else None
                    row["bookshelf3"] = bookshelves[2] if len(bookshelves) > 2 else None
                    
                    has_formats = g.objects(ebook, dcterms.hasFormat)
                    has_formats = [str(f) for f in has_formats]
                    row["hasFormat"] = has_formats

                    df = pd.DataFrame(row,columns=["publisher", "license", "issued", "rights", "downloads", "creator_name",
                                        "creator_birthdate", "creator_deathdate", "creator_alias", "creator_webpage",
                                        "title", "description", "language", "subject1", "subject2", "subject3",
                                        "subject4", "bookshelf1", "bookshelf2", "bookshelf3", "hasFormat"])
                    books_metadata.append(df)
    return books_metadata

# %%
#df_list = parsemetadataNEW("./notebooks/cache/epub/")

# %%
#df = pd.concat(df_list)

# %%
#df_multindex = df.set_index(['title', 'hasFormat'])

# %%
#df_multindex.to_parquet('metadata_multindex.parquet')

# %%
#df_multindex.to_json('metadata_multindex.json', orient='records')

# %%
df = pd.read_parquet("./metadata_multindex.parquet")

# %%
import urllib3

# %%
data = urllib3.urlopen(df.at[])

# %%
df = df.reset_index()

# %%
df = df.groupby("title").agg(lambda x: x.tolist()[0] if len(set(x.tolist()))== 1 else x.tolist()).reset_index()

# %%
df
# Out:
#                                                    title  \
# 0      !Tention: A Story of Boy-Life during the Penin...
# 1      "'Tis Sixty Years Since"\r\nAddress of Charles...
# 2      "1683-1920"\r\nThe Fourteen Points and What Be...
# 3                            "1812" Napoleon I in Russia
# 4                                                 "1914"
# ...                                                  ...
# 69377                                                鹽鐵論
# 69378                                                麟兒報
# 69379                                                黃繡球
# 69380                                               黄帝宅經
# 69381                                                龍川詞
#
#                                                hasFormat          publisher  \
# 0      [https://www.gutenberg.org/ebooks/21374.html.i...  Project Gutenberg
# 1      [https://www.gutenberg.org/ebooks/9996.html.im...  Project Gutenberg
# 2      [https://www.gutenberg.org/ebooks/50075.html.i...  Project Gutenberg
# 3      [https://www.gutenberg.org/ebooks/51418.html.i...  Project Gutenberg
# 4      [https://www.gutenberg.org/ebooks/66846.html.i...  Project Gutenberg
# ...                                                  ...                ...
# 69377  [https://www.gutenberg.org/ebooks/26920.html.i...  Project Gutenberg
# 69378  [https://www.gutenberg.org/ebooks/27399.html.i...  Project Gutenberg
# 69379  [https://www.gutenberg.org/ebooks/25147.html.i...  Project Gutenberg
# 69380  [https://www.gutenberg.org/ebooks/27858.html.i...  Project Gutenberg
# 69381  [https://www.gutenberg.org/ebooks/26873.html.i...  Project Gutenberg
#
#                                 license      issued  \
# 0      http://www.gutenberg.org/license  2007-05-08
# 1      http://www.gutenberg.org/license  2006-02-01
# 2      http://www.gutenberg.org/license  2015-09-29
# 3      http://www.gutenberg.org/license  2016-03-12
# 4      http://www.gutenberg.org/license  2021-11-30
# ...                                 ...         ...
# 69377  http://www.gutenberg.org/license  2008-10-14
# 69378  http://www.gutenberg.org/license  2008-12-03
# 69379  http://www.gutenberg.org/license  2008-04-23
# 69380  http://www.gutenberg.org/license  2009-01-21
# 69381  http://www.gutenberg.org/license  2008-10-11
#
#                           rights downloads  \
# 0      Public domain in the USA.       641
# 1      Public domain in the USA.        43
# 2      Public domain in the USA.        84
# 3      Public domain in the USA.        46
# 4      Public domain in the USA.        42
# ...                          ...       ...
# 69377  Public domain in the USA.        47
# 69378  Public domain in the USA.        46
# 69379  Public domain in the USA.        31
# 69380  Public domain in the USA.        26
# 69381  Public domain in the USA.        21
#
#                               creator_name creator_birthdate  \
# 0                    Fenn, George Manville              1831
# 1                   Adams, Charles Francis              1835
# 2             Schrader, Frederick Franklin              1857
# 3        Vereshchagin, Vasilïĭ Vasilʹevich              1842
# 4                            Oxenham, John              1852
# ...                                    ...               ...
# 69377  Huan, Kuan, active 1st century B.C.              None
# 69378                            Anonymous              None
# 69379                                 None              None
# 69380                              Unknown              None
# 69381                          Chen, Liang              1143
#
#       creator_deathdate  ...  \
# 0                  1909  ...
# 1                  1915  ...
# 2                  None  ...
# 3                  1904  ...
# 4                  1941  ...
# ...                 ...  ...
# 69377              None  ...
# 69378              None  ...
# 69379              None  ...
# 69380              None  ...
# 69381              1194  ...
#
#                                          creator_webpage description language  \
# 0      https://en.wikipedia.org/wiki/George_Manville_...        None       en
# 1      https://en.wikipedia.org/wiki/Charles_Francis_...        None       en
# 2                                                   None        None       en
# 3       http://en.wikipedia.org/wiki/Vasily_Vereshchagin        None       en
# 4      https://en.wikipedia.org/wiki/William_Arthur_D...        None       en
# ...                                                  ...         ...      ...
# 69377                                               None        None       zh
# 69378       https://en.wikipedia.org/wiki/Anonymous_work        None       zh
# 69379                                               None        None       zh
# 69380         http://www.gutenberg.org/ebooks/author/216        None       zh
# 69381    http://zh.wikipedia.org/wiki/%E9%99%88%E4%BA%AE        None       zh
#
#                                                 subject1  \
# 0          Peninsular War, 1807-1814 -- Juvenile fiction
# 1                                     Philosophy, Modern
# 2                               Germans -- United States
# 3      Napoleonic Wars, 1800-1815 -- Campaigns -- Russia
# 4                        World War, 1914-1918 -- Fiction
# ...                                                  ...
# 69377                     Government monopolies -- China
# 69378                                    Chinese fiction
# 69379                                                 PL
# 69380                                          Feng shui
# 69381                                Ci (Chinese poetry)
#
#                                   subject2                          subject3  \
# 0                                       PZ                              None
# 1                                        B                              None
# 2      World War, 1914-1918 -- Miscellanea                              E151
# 3           Russia -- History -- 1801-1917                                DC
# 4                                       PR                              None
# ...                                    ...                               ...
# 69377     Salt industry and trade -- China  Iron industry and trade -- China
# 69378                                   PL                              None
# 69379                                 None                              None
# 69380                                   PL                              None
# 69381                                   PL                              None
#
#       subject4 bookshelf1 bookshelf2 bookshelf3
# 0         None       None       None       None
# 1         None       None       None       None
# 2         None       None       None       None
# 3         None       None       None       None
# 4         None       None       None       None
# ...        ...        ...        ...        ...
# 69377       HD       None       None       None
# 69378     None       None       None       None
# 69379     None       None       None       None
# 69380     None       None       None       None
# 69381     None       None       None       None
#
# [69382 rows x 21 columns]

# %%
df.to_parquet("./data/metadata.parquet")
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 df.to_parquet("./data/metadata.parquet")
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/pandas/core/frame.py:2889, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2802 """
#    2803 Write a DataFrame to the binary parquet format.
#    2804
#    (...)
#    2885 >>> content = f.read()
#    2886 """
#    2887 from pandas.io.parquet import to_parquet
# -> 2889 return to_parquet(
#    2890     self,
#    2891     path,
#    2892     engine,
#    2893     compression=compression,
#    2894     index=index,
#    2895     partition_cols=partition_cols,
#    2896     storage_options=storage_options,
#    2897     **kwargs,
#    2898 )
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/pandas/io/parquet.py:411, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, **kwargs)
#     407 impl = get_engine(engine)
#     409 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 411 impl.write(
#     412     df,
#     413     path_or_buf,
#     414     compression=compression,
#     415     index=index,
#     416     partition_cols=partition_cols,
#     417     storage_options=storage_options,
#     418     **kwargs,
#     419 )
#     421 if path is None:
#     422     assert isinstance(path_or_buf, io.BytesIO)
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/pandas/io/parquet.py:159, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, **kwargs)
#     156 if index is not None:
#     157     from_pandas_kwargs["preserve_index"] = index
# --> 159 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     161 path_or_handle, handles, kwargs["filesystem"] = _get_path_or_handle(
#     162     path,
#     163     kwargs.pop("filesystem", None),
#    (...)
#     166     is_dir=partition_cols is not None,
#     167 )
#     168 if (
#     169     isinstance(path_or_handle, io.BufferedWriter)
#     170     and hasattr(path_or_handle, "name")
#     171     and isinstance(path_or_handle.name, (str, bytes))
#     172 ):
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/pyarrow/table.pxi:3681, in pyarrow.lib.Table.from_pandas()
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/pyarrow/pandas_compat.py:624, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     622     for i, maybe_fut in enumerate(arrays):
#     623         if isinstance(maybe_fut, futures.Future):
# --> 624             arrays[i] = maybe_fut.result()
#     626 types = [x.type for x in arrays]
#     628 if schema is None:
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/concurrent/futures/_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/pyarrow/pandas_compat.py:598, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     593 except (pa.ArrowInvalid,
#     594         pa.ArrowNotImplementedError,
#     595         pa.ArrowTypeError) as e:
#     596     e.args += ("Conversion failed for column {!s} with type {!s}"
#     597                .format(col.name, col.dtype),)
# --> 598     raise e
#     599 if not field_nullable and result.null_count > 0:
#     600     raise ValueError("Field {} was non-nullable but pandas column "
#     601                      "had {} null values".format(str(field),
#     602                                                  result.null_count))
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/pyarrow/pandas_compat.py:592, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     589     type_ = field.type
#     591 try:
# --> 592     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#     593 except (pa.ArrowInvalid,
#     594         pa.ArrowNotImplementedError,
#     595         pa.ArrowTypeError) as e:
#     596     e.args += ("Conversion failed for column {!s} with type {!s}"
#     597                .format(col.name, col.dtype),)
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/pyarrow/array.pxi:323, in pyarrow.lib.array()
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/pyarrow/array.pxi:83, in pyarrow.lib._ndarray_to_array()
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/pyarrow/error.pxi:100, in pyarrow.lib.check_status()
#
# ArrowInvalid: ('cannot mix list and non-list, non-null values', 'Conversion failed for column hasFormat with type object')

# %%
df_new =df.reset_index()

# %%
df_new.rename({'index':'ID'},axis=1, inplace=True)

# %%
df = df_new

# %%
df
# Out:
#           ID                                              title  \
# 0          0  !Tention: A Story of Boy-Life during the Penin...
# 1          1  "'Tis Sixty Years Since"\r\nAddress of Charles...
# 2          2  "1683-1920"\r\nThe Fourteen Points and What Be...
# 3          3                        "1812" Napoleon I in Russia
# 4          4                                             "1914"
# ...      ...                                                ...
# 69377  69377                                                鹽鐵論
# 69378  69378                                                麟兒報
# 69379  69379                                                黃繡球
# 69380  69380                                               黄帝宅經
# 69381  69381                                                龍川詞
#
#                                                hasFormat          publisher  \
# 0      [https://www.gutenberg.org/ebooks/21374.html.i...  Project Gutenberg
# 1      [https://www.gutenberg.org/ebooks/9996.html.im...  Project Gutenberg
# 2      [https://www.gutenberg.org/ebooks/50075.html.i...  Project Gutenberg
# 3      [https://www.gutenberg.org/ebooks/51418.html.i...  Project Gutenberg
# 4      [https://www.gutenberg.org/ebooks/66846.html.i...  Project Gutenberg
# ...                                                  ...                ...
# 69377  [https://www.gutenberg.org/ebooks/26920.html.i...  Project Gutenberg
# 69378  [https://www.gutenberg.org/ebooks/27399.html.i...  Project Gutenberg
# 69379  [https://www.gutenberg.org/ebooks/25147.html.i...  Project Gutenberg
# 69380  [https://www.gutenberg.org/ebooks/27858.html.i...  Project Gutenberg
# 69381  [https://www.gutenberg.org/ebooks/26873.html.i...  Project Gutenberg
#
#                                 license      issued  \
# 0      http://www.gutenberg.org/license  2007-05-08
# 1      http://www.gutenberg.org/license  2006-02-01
# 2      http://www.gutenberg.org/license  2015-09-29
# 3      http://www.gutenberg.org/license  2016-03-12
# 4      http://www.gutenberg.org/license  2021-11-30
# ...                                 ...         ...
# 69377  http://www.gutenberg.org/license  2008-10-14
# 69378  http://www.gutenberg.org/license  2008-12-03
# 69379  http://www.gutenberg.org/license  2008-04-23
# 69380  http://www.gutenberg.org/license  2009-01-21
# 69381  http://www.gutenberg.org/license  2008-10-11
#
#                           rights downloads  \
# 0      Public domain in the USA.       641
# 1      Public domain in the USA.        43
# 2      Public domain in the USA.        84
# 3      Public domain in the USA.        46
# 4      Public domain in the USA.        42
# ...                          ...       ...
# 69377  Public domain in the USA.        47
# 69378  Public domain in the USA.        46
# 69379  Public domain in the USA.        31
# 69380  Public domain in the USA.        26
# 69381  Public domain in the USA.        21
#
#                               creator_name creator_birthdate  ...  \
# 0                    Fenn, George Manville              1831  ...
# 1                   Adams, Charles Francis              1835  ...
# 2             Schrader, Frederick Franklin              1857  ...
# 3        Vereshchagin, Vasilïĭ Vasilʹevich              1842  ...
# 4                            Oxenham, John              1852  ...
# ...                                    ...               ...  ...
# 69377  Huan, Kuan, active 1st century B.C.              None  ...
# 69378                            Anonymous              None  ...
# 69379                                 None              None  ...
# 69380                              Unknown              None  ...
# 69381                          Chen, Liang              1143  ...
#
#                                          creator_webpage description language  \
# 0      https://en.wikipedia.org/wiki/George_Manville_...        None       en
# 1      https://en.wikipedia.org/wiki/Charles_Francis_...        None       en
# 2                                                   None        None       en
# 3       http://en.wikipedia.org/wiki/Vasily_Vereshchagin        None       en
# 4      https://en.wikipedia.org/wiki/William_Arthur_D...        None       en
# ...                                                  ...         ...      ...
# 69377                                               None        None       zh
# 69378       https://en.wikipedia.org/wiki/Anonymous_work        None       zh
# 69379                                               None        None       zh
# 69380         http://www.gutenberg.org/ebooks/author/216        None       zh
# 69381    http://zh.wikipedia.org/wiki/%E9%99%88%E4%BA%AE        None       zh
#
#                                                 subject1  \
# 0          Peninsular War, 1807-1814 -- Juvenile fiction
# 1                                     Philosophy, Modern
# 2                               Germans -- United States
# 3      Napoleonic Wars, 1800-1815 -- Campaigns -- Russia
# 4                        World War, 1914-1918 -- Fiction
# ...                                                  ...
# 69377                     Government monopolies -- China
# 69378                                    Chinese fiction
# 69379                                                 PL
# 69380                                          Feng shui
# 69381                                Ci (Chinese poetry)
#
#                                   subject2                          subject3  \
# 0                                       PZ                              None
# 1                                        B                              None
# 2      World War, 1914-1918 -- Miscellanea                              E151
# 3           Russia -- History -- 1801-1917                                DC
# 4                                       PR                              None
# ...                                    ...                               ...
# 69377     Salt industry and trade -- China  Iron industry and trade -- China
# 69378                                   PL                              None
# 69379                                 None                              None
# 69380                                   PL                              None
# 69381                                   PL                              None
#
#       subject4 bookshelf1 bookshelf2 bookshelf3
# 0         None       None       None       None
# 1         None       None       None       None
# 2         None       None       None       None
# 3         None       None       None       None
# 4         None       None       None       None
# ...        ...        ...        ...        ...
# 69377       HD       None       None       None
# 69378     None       None       None       None
# 69379     None       None       None       None
# 69380     None       None       None       None
# 69381     None       None       None       None
#
# [69382 rows x 22 columns]

# %%
import requests
df_new = []
for i,row in df.iterrows():
    try:
        txt_url = next(filter(lambda x: x.endswith(".txt.utf-8"),row.hasFormat))
        format_=".txt"
        encoding="utf-8"
    except StopIteration:
        txt_url = next(filter(lambda x: x.endswith(".txt"), row.hasFormat))
        format_=".txt"
        encoding="UNKNOWN"
    except:
        txt_url = ""
        format=""
        encoding=""
    
    if txt_url != "":
        res = requests.get(txt_url)
        if res.status_code == 200:
            text = res.text

    df_new.append({
        'metadataID':row.ID,
        'title':row.title,
        'format':format_,
        'encoding': encoding,
        'text' : text,
        'language':row.language,
        })
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[95], line 18
#      15     encoding=""
#      17 if txt_url != "":
# ---> 18     res = requests.get(txt_url)
#      19     if res.status_code == 200:
#      20         text = res.text
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/requests/sessions.py:725, in Session.send(self, request, **kwargs)
#     722 if allow_redirects:
#     723     # Redirect resolving generator.
#     724     gen = self.resolve_redirects(r, request, **kwargs)
# --> 725     history = [resp for resp in gen]
#     726 else:
#     727     history = []
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/requests/sessions.py:725, in <listcomp>(.0)
#     722 if allow_redirects:
#     723     # Redirect resolving generator.
#     724     gen = self.resolve_redirects(r, request, **kwargs)
# --> 725     history = [resp for resp in gen]
#     726 else:
#     727     history = []
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/requests/sessions.py:266, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 266     resp = self.send(
#     267         req,
#     268         stream=stream,
#     269         timeout=timeout,
#     270         verify=verify,
#     271         cert=cert,
#     272         proxies=proxies,
#     273         allow_redirects=False,
#     274         **adapter_kwargs,
#     275     )
#     277     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     279     # extract redirect url, if any, for the next loop
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/requests/sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/requests/models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/urllib3/response.py:940, in HTTPResponse.stream(self, amt, decode_content)
#     938 else:
#     939     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# --> 940         data = self.read(amt=amt, decode_content=decode_content)
#     942         if data:
#     943             yield data
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/urllib3/response.py:879, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     876     if len(self._decoded_buffer) >= amt:
#     877         return self._decoded_buffer.get(amt)
# --> 879 data = self._raw_read(amt)
#     881 flush_decoder = False
#     882 if amt is None:
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/urllib3/response.py:814, in HTTPResponse._raw_read(self, amt)
#     811 fp_closed = getattr(self._fp, "closed", False)
#     813 with self._error_catcher():
# --> 814     data = self._fp_read(amt) if not fp_closed else b""
#     815     if amt is not None and amt != 0 and not data:
#     816         # Platform-specific: Buggy versions of Python.
#     817         # Close the connection when no data is returned
#    (...)
#     822         # not properly close the connection in all cases. There is
#     823         # no harm in redundantly calling close.
#     824         self._fp.close()
#
# File ~/Projects/GutenbergOnomasticsExplorer/.venv/lib/python3.10/site-packages/urllib3/response.py:799, in HTTPResponse._fp_read(self, amt)
#     796     return buffer.getvalue()
#     797 else:
#     798     # StringIO doesn't like amt=None
# --> 799     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/http/client.py:465, in HTTPResponse.read(self, amt)
#     462 if self.length is not None and amt > self.length:
#     463     # clip the read to the "end of response"
#     464     amt = self.length
# --> 465 s = self.fp.read(amt)
#     466 if not s and amt:
#     467     # Ideally, we would raise IncompleteRead if the content-length
#     468     # wasn't satisfied, but it might break compatibility.
#     469     self._close_conn()
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
len(df_new)
# Out:
# 405

# %%
df_books = pd.DataFrame(df_new)

# %%
df_books.to_parquet("./data/gutenberg")
